# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#import pydensecrf.densecrf as dcrf

from mmdet.apis import init_detector, inference_detector

import numpy as np
import cv2
import random


config_file = r"output.py"
checkpoint_file = r"C:\Users\philmarq\Downloads\2023-01-03 Custom - Cog_Classifier\Custom - Cog_Classifier---od---001.pt"

device = 'cuda:0'

model = init_detector(config_file, checkpoint_file, device=device)

# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#import pydensecrf.densecrf as dcrf

from mmdet.apis import init_detector, inference_detector

import numpy as np
import cv2
import random

config_file = r"C:\Users\philmarq\source\repos\MMWrapperRepo\glomerli_cells_swint_300queries\swin_t.py"
checkpoint_file = r"C:\Users\philmarq\source\repos\MMWrapperRepo\glomerli_cells_swint_300queries\best_coco_bbox_mAP_epoch_69.pth"
device = 'cuda:0'

model = init_detector(config_file, checkpoint_file, device=device)

# Load image


colors = [(255,0,0), (125,0,0), (0,255,0), (50, 255,0), (0,25,255), (0, 125, 0), (0, 125, 125)]
root = r"C:\Users\philmarq\source\repos\Daten\Coco\Coco\images"
colors = [(random.randint(0,255), random.randint(0,255), random.randint(0,255)) for i in range(10)]
for file in os.listdir(root):
    img = os.path.join(root, file)
    result = inference_detector(model, img)
    
    

    color = (255,0,0)
    
    image = cv2.imread(img)
    orig = image.copy()

    #image[image>0] = 0
    masks = result.pred_instances.masks.cpu().numpy()
    scores = result.pred_instances.scores.cpu().numpy()
    labels = result.pred_instances.labels.cpu().numpy()
    bboxes = result.pred_instances.bboxes.cpu().numpy()
    thresh = 0.25
    
    for mask, score,label, bbox in zip(masks, scores,  labels, bboxes):
        #print(score)
        if score > thresh:
            if label == 0 or True:  # For label == 0, draw contours
                mask = mask.astype(np.uint8)
                contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
                #contours = connect_closest_contours(contours, image, angle_tolerance = 5, fixed_threshold=50, pixel_threshold = 3)
                color  = np.random.rand(3) * 255
                #print(label)
                cv2.drawContours(image, contours, -1, colors[label], -1)
            else:  # For other labels, draw bounding boxes
                color = colors[label]
                x1, y1, x2, y2 = bbox.astype(np.int32)
                cv2.rectangle(image, (x1, y1), (x2, y2), color, 1)
    
    cv2.imwrite(os.path.join("outputall", file), image)

# %%
import cv2
x = cv2.imread(r"C:\HSA\HSA-Data\projects\48ba5d5c-8d6c-4eb4-9ceb-2ddd6c8cb030\dataset\val2017\86_14_betaAmy2022042315.35.18_0s_0r_2880x_0y_.png") * 50
cv2.imwrite("xd.png", x)

# %%
import os
import random
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
#import pydensecrf.densecrf as dcrf

from mmdet.apis import init_detector, inference_detector

import numpy as np
import cv2



config_file = r"C:\Users\philmarq\source\repos\MMWrapperRepo\megdata\swin_s.py"
checkpoint_file = r"C:\Users\philmarq\source\repos\MMWrapperRepo\megdata\best_coco_bbox_mAP_epoch_83.pth"

device = 'cuda:0'

model = init_detector(config_file, checkpoint_file, device=device)

# Load image


colors = [(255,0,0), (125,0,0), (0,255,0), (50, 255,0), (0,25,255), (0, 125, 0)]
root = r"C:\HSA\HSA-Data\projects\2cc375cc-4067-40f6-a23d-387ec7422611\dataset\images"
for file in os.listdir(root):
    img = os.path.join(root, file)
    result = inference_detector(model, img)
    
    

    color = (255,0,0)
    red = random.randint(0, 255)
    green = random.randint(0, 255)
    blue = random.randint(0, 255)

    # Create a random color tuple
    color = (red, green, blue)
    image = cv2.imread(img)
    #image[image>0] = 0
    masks = result.pred_instances.masks.cpu().numpy()
    scores = result.pred_instances.scores.cpu().numpy()
    labels = result.pred_instances.labels.cpu().numpy()
    bboxes = result.pred_instances.bboxes.cpu().numpy()
    thresh = 0.75
    
    for mask, score,label, bbox in zip(masks, scores,  labels, bboxes):
        if score > thresh:
            if label == 0:  # For label == 0, draw contours
                mask = mask.astype(np.uint8)
                red = random.randint(0, 255)
                green = random.randint(0, 255)
                blue = random.randint(0, 255)

                # Create a random color tuple
                color = (red, green, blue)
                contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
                #contours = connect_closest_contours(contours, image, angle_tolerance = 5, fixed_threshold=50, pixel_threshold = 3)
                #color  = np.random.rand(3) * 255
                cv2.drawContours(image, contours, -1, color, -1)
                #x1, y1, x2, y2 = bbox.astype(np.int32)
                #cv2.rectangle(image, (x1, y1), (x2, y2), color, 1)
            else:  # For other labels, draw bounding boxes
                color = colors[label]
                x1, y1, x2, y2 = bbox.astype(np.int32)
                cv2.rectangle(image, (x1, y1), (x2, y2), color, 1)
    
    cv2.imwrite(os.path.join("outputall", file), image)

# %%
def predict_mmdet_instance_seg(model, img: np.ndarray) -> np.ndarray:
    """
    Analyze image with instance seg model of comdl module

    Args:
        img (np.ndarray): image to analyze

    Returns:
        np.ndarray: mask with segmentation predictions of model
    """

    result = model.predict(img)

    classes = list(range(1, 1 + 1))
    candidates = []

    masks = result.pred_instances.masks.cpu().numpy()
    scores = result.pred_instances.scores.cpu().numpy()
    labels = result.pred_instances.labels.cpu().numpy()
    bboxes = result.pred_instances.bboxes.cpu().numpy()

    for mask, score,label, bbox in zip(masks, scores,  labels, bboxes):
        bbox = bbox.astype(int)
        score = score.astype(float)
        if score < 0.75:
            continue
        pts = np.where(mask.astype(float) > 0)
        candidates.append((score, bbox, pts, label))

    # sort by object score
    candidates.sort(key=lambda x: x[0], reverse=True)

    img_shape = (img.shape[0], img.shape[1])
    final = np.zeros(img_shape, dtype="uint8")
    contour_mask = np.zeros(img_shape, dtype="uint8")
    empty = np.zeros((img.shape[0], img.shape[1], 1))
    for cand in candidates:
        score = cand[0]
        bbox = cand[1]
        pts = cand[2]
        cls = cand[3]

        mas = np.zeros((img.shape[0], img.shape[1]))
        for y, x in zip(pts[0], pts[1]):
            mas[y, x] = 255

        # fix contour in contour
        if True or np.count_nonzero(final[mas == 255]) <= 100:
            final[mas == 255] = random.randint(50, 255)

            single_mask = mas.astype("uint8")
            kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
            single_mask = cv2.dilate(single_mask, kernel, iterations=1)

            # create image with all contours
            single_contours = cv2.findContours(
                single_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE
            )[0]
            contours = []
            for cnt in single_contours:
                contours.append(cnt)

            cv2.drawContours(contour_mask, contours, -1, classes[cls], -1)
            cv2.drawContours(contour_mask, contours, -1, 0, 1)
            cv2.drawContours(
                contour_mask, contours, -1, 0, 1, cv2.LINE_4
            )  # 2nd time needed to prevent pixel issue

    return contour_mask


import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#import pydensecrf.densecrf as dcrf

from mmdet.apis import init_detector, inference_detector

import numpy as np
import cv2
import random




config_file = r"C:\Users\philmarq\source\repos\MMWrapperRepo\swinunetblitze\swin_unet.py"
checkpoint_file = r"C:\Users\philmarq\source\repos\MMWrapperRepo\swinunetblitze\best_mIoU_epoch_17.pth"

device = 'cuda:0'

from mmwrapper.src.api import InferenceModel
model = InferenceModel(checkpoint_file, config_file)

# Load image


colors = [(255,0,0), (125,0,0), (0,255,0), (50, 255,0), (0,25,255), (0, 125, 0)]
root = r"C:\HSA\HSA-Data\projects\007480d6-ed49-47ca-b0ec-43d41349bf31\dataset\valid\images"
for file in os.listdir(root):
    img = os.path.join(root, file)
    img = cv2.imread(img)
    result = predict_mmdet_instance_seg(model, img) 
    
    cv2.imwrite(os.path.join("outputall", f"hsa_mmwrap_{file}"), result*100)

# %%
from mmengine import Config

# %%
config_file = r"C:\Users\philmarq\source\repos\mmdetectionnew\segmentationswins\swin_s_upper.py"
is_detetion = Config.fromfile(config_file)['train_pipeline'][-1]['type'] #== "PackDetInputs"

# %%
is_detetion

# %%
from mmseg.apis import init_model, inference_model
from mmdet.apis import init_detector, inference_detector

class InferenceModel:
    def __init__(self, checkpoint_file, config_file, device = "cuda"):
        self.is_detection = Config.fromfile(config_file)['train_pipeline'][-1]['type'] == "PackDetInputs"
        print(Config.fromfile(config_file)['train_pipeline'][-1])
        print(self.is_detection)
        if self.is_detection:
            self.model = init_detector(config_file, checkpoint_file, device=device)
            self.forward = inference_detector
        else:
            self.model = init_model(config_path, checkpoint_path, device=device)
            self.forward = inference_model
    def predict(self, imgs):
        return self.forward(self.model, imgs)

# %%
config_path = r"C:\Users\philmarq\source\repos\MMWrapperRepo\segmentationtest\20230805_125344\vis_data\config.py"
checkpoint_path = r"C:\Users\philmarq\source\repos\MMWrapperRepo\segmentationtest\best_mIoU_epoch_67.pth"
inf = InferenceModel(checkpoint_file, config_path)

# %%
inf.predict(imgs[0:1])

# %%
imgs

# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#import pydensecrf.densecrf as dcrf

from mmdet.apis import init_detector, inference_detector

import numpy as np
import cv2



config_file = r"C:\HSA\HSA-Data\custom_models\verified_models\Custom - Cells_i-od_Cells_i-sw_512px_-1_rgb\20231024_144257\vis_data\config.py"
checkpoint_file = r"C:\HSA\HSA-Data\custom_models\verified_models\Custom - Cells_i-od_Cells_i-sw_512px_-1_rgb\best_coco_bbox_mAP_epoch_5.pth"

device = 'cuda:0'

model = init_detector(config_file, checkpoint_file, device=device)

# Load image


colors = [(255,0,0), (125,0,0), (0,255,0), (50, 255,0), (0,25,255), (0, 125, 0)]
root = r"C:\HSA\HSA-Data\projects\b50d88c1-7b5d-4fe0-a5d4-ca0b73b57925\dataset\images"
imgs = []
for file in os.listdir(root):
    img = os.path.join(root, file)
    imgs.append(img)
    continue
    result = inference_detector(model, img)
    
    

    color = (255,0,0)
    image = cv2.imread(img)
    orig = image.copy()

    #image[image>0] = 0
    #masks = result.pred_instances.masks.cpu().numpy()
    scores = result.pred_instances.scores.cpu().numpy()
    labels = result.pred_instances.labels.cpu().numpy()
    bboxes = result.pred_instances.bboxes.cpu().numpy()
    thresh = 0.35
    
    for  score,label, bbox in zip(scores,  labels, bboxes):
        if score > thresh:
            color = colors[label]
            x1, y1, x2, y2 = bbox.astype(np.int32)
            cv2.rectangle(image, (x1, y1), (x2, y2), color, 1)
    
    cv2.imwrite(os.path.join("outputall", file), image)

# %%
from mmseg.registry import MODELS
import torch
import torch.nn as nn
from mmcv.cnn import ConvModule

from mmseg.registry import MODELS
from mmseg.models.decode_heads.decode_head import BaseDecodeHead


from mmseg.models.utils import resize,UpConvBlock, Upsample
from mmseg.models.decode_heads.psp_head import PPM

import torch.utils.checkpoint as cp
from mmcv.cnn import ConvModule, build_activation_layer, build_norm_layer
from mmengine.model import BaseModule
from mmengine.utils.dl_utils.parrots_wrapper import _BatchNorm

class BasicConvBlock(nn.Module):
    """Basic convolutional block for UNet.

    This module consists of several plain convolutional layers.

    Args:
        in_channels (int): Number of input channels.
        out_channels (int): Number of output channels.
        num_convs (int): Number of convolutional layers. Default: 2.
        stride (int): Whether use stride convolution to downsample
            the input feature map. If stride=2, it only uses stride convolution
            in the first convolutional layer to downsample the input feature
            map. Options are 1 or 2. Default: 1.
        dilation (int): Whether use dilated convolution to expand the
            receptive field. Set dilation rate of each convolutional layer and
            the dilation rate of the first convolutional layer is always 1.
            Default: 1.
        with_cp (bool): Use checkpoint or not. Using checkpoint will save some
            memory while slowing down the training speed. Default: False.
        conv_cfg (dict | None): Config dict for convolution layer.
            Default: None.
        norm_cfg (dict | None): Config dict for normalization layer.
            Default: dict(type='BN').
        act_cfg (dict | None): Config dict for activation layer in ConvModule.
            Default: dict(type='ReLU').
        dcn (bool): Use deformable convolution in convolutional layer or not.
            Default: None.
        plugins (dict): plugins for convolutional layers. Default: None.
    """

    def __init__(self,
                 in_channels,
                 out_channels,
                 num_convs=2,
                 stride=1,
                 dilation=1,
                 with_cp=False,
                 conv_cfg=None,
                 norm_cfg=dict(type='BN'),
                 act_cfg=dict(type='ReLU'),
                 dcn=None,
                 plugins=None):
        super().__init__()
        assert dcn is None, 'Not implemented yet.'
        assert plugins is None, 'Not implemented yet.'

        self.with_cp = with_cp
        convs = []
        for i in range(num_convs):
            convs.append(
                ConvModule(
                    in_channels=in_channels if i == 0 else out_channels,
                    out_channels=out_channels,
                    kernel_size=3,
                    stride=stride if i == 0 else 1,
                    dilation=1 if i == 0 else dilation,
                    padding=1 if i == 0 else dilation,
                    conv_cfg=conv_cfg,
                    norm_cfg=norm_cfg,
                    act_cfg=act_cfg))

        self.convs = nn.Sequential(*convs)

    def forward(self, x):
        """Forward function."""

        if self.with_cp and x.requires_grad:
            out = cp.checkpoint(self.convs, x)
        else:
            out = self.convs(x)
        return out


@MODELS.register_module()
class UnetDecoder(BaseDecodeHead):
    """Unified Perceptual Parsing for Scene Understanding.

    This head is the implementation of `UPerNet
    <https://arxiv.org/abs/1807.10221>`_.

    Args:
        pool_scales (tuple[int]): Pooling scales used in Pooling Pyramid
            Module applied on the last feature. Default: (1, 2, 3, 6).
    """

    def __init__(self, num_stages = 3, **kwargs):
        super().__init__(input_transform='multiple_select', **kwargs)
        # PSP Module
        upsample_cfg=dict(type='InterpConv')
        self.decoder = nn.ModuleList()
        self.num_stages = num_stages
#         self.encoder = []
#         self.encoder.append(BasicConvBlock(
#                     in_channels=self.in_channels[-1],
#                     out_channels=self.in_channels[-1] ** 2,
#                     num_convs=2,
#                     stride=1,
#                     dilation=1,
#                     with_cp=False,
#                     conv_cfg=None,
#                     norm_cfg=dict(type='BN'),
#                     act_cfg=dict(type='ReLU'),
#                     dcn=None,
#                     plugins=None))
        for i in range(num_stages - 1):
            #print(self.in_channels[num_stages - i-1])
            #print(self.in_channels[num_stages -i-2])
            self.decoder.append(
                    UpConvBlock(
                        conv_block=BasicConvBlock,
                        in_channels=self.in_channels[num_stages - i-1],
                        skip_channels=self.in_channels[num_stages -i-2],
                        out_channels=self.in_channels[num_stages -i-2],
                        num_convs=2,
                        stride=1,
                        dilation=1,
                        with_cp=False,
                        conv_cfg=None,
                        norm_cfg=dict(type='BN'),
                        act_cfg=dict(type='ReLU'),
                        upsample_cfg=upsample_cfg,
                        dcn=None,
                        plugins=None))



    def _forward_feature(self, inputs):
        """Forward function for feature maps before classifying each pixel with
        ``self.cls_seg`` fc.

        Args:
            inputs (list[Tensor]): List of multi-level img features.

        Returns:
            feats (Tensor): A tensor of shape (batch_size, self.channels,
                H, W) which is feature map for last layer of decoder head.
        """
        inputs = self._transform_inputs(inputs)

#         print(len(inputs))
#         for inp in inputs:
#             print(inp.shape)
        x = inputs[-1]
        for i in range(self.num_stages - 1):
            x = self.decoder[i](inputs[-2-i],x)
            #print(x.shape)
        #bottleneck = self.bottleneck(inputs[-1])
        #print(bottleneck.shape)
        return x

    def forward(self, inputs):
        """Forward function."""
        output = self._forward_feature(inputs)
        output = self.cls_seg(output)
        return output

# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

from mmseg.apis import init_model, inference_model
from mmseg.apis.inference import _preprare_data
import tifffile
config_path = r"C:\Users\philmarq\source\repos\MMWrapperRepo\swinunetblitze\20231009_201250\vis_data\config.py"
checkpoint_path = r"C:\Users\philmarq\source\repos\MMWrapperRepo\swinunetblitze\best_mIoU_epoch_23.pth"
model = init_model(config_path, checkpoint_path)

import torch
import cv2
base = r"C:\Users\philmarq\Downloads\dataset_seg_2ch_256_updated\dataset_seg_2ch_256_updated\valid\images/"
labels = base.replace("images", "labels")
for file in os.listdir(base):
    img = tifffile.imread(os.path.join(base, file))
    result = inference_model(model, img)
    label = cv2.imread(os.path.join(labels, file), 0)
    logits =  result.seg_logits.data
    
    logits = torch.argmax(logits, dim=0).unsqueeze(0)
    cv2.imwrite(os.path.join("outputall", file.replace(".tif", ".png")), (result.pred_sem_seg.data.permute(1,2,0).cpu().numpy() + 0) * 50.)
    #cv2.imwrite(os.path.join("outputall", "orig_" + file), label * 50.)
    #cv2.imwrite(os.path.join("output", file), logits.permute(1,2,0).cpu().numpy() * 50.)

# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from mmseg.apis import init_model as init_model_mmseg
from mmseg.apis import  inference_model as inference_model_mmesg
from mmseg.apis.inference import _preprare_data

config_path = r"C:\Users\philmarq\source\repos\MMWrapperRepo\segmentationtest\20230805_125344\vis_data\config.py"
checkpoint_path = r"C:\Users\philmarq\source\repos\MMWrapperRepo\segmentationtest\best_mIoU_epoch_67.pth"
model = init_model_mmseg(config_path, checkpoint_path)
import torch
import cv2
base = r"C:/HSA/HSA-Data/projects/035c4d1b-ddad-4bb9-834b-7f2d2658655d/dataset\valid\images"
label_base = r"C:/HSA/HSA-Data/projects/035c4d1b-ddad-4bb9-834b-7f2d2658655d/dataset\valid\labels"
output_dir = "outputall"

os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(base):
    image_path = os.path.join(base, file)
    label_path = os.path.join(label_base, file)

    result = inference_model_mmesg(model, image_path)
    logits = result.seg_logits.data
    logits = torch.argmax(logits, dim=0).unsqueeze(0)

    # Load the ground truth labels
    label = cv2.imread(label_path, cv2.IMREAD_GRAYSCALE) * 50.

    # Combine prediction and label side by side
    combined_img = cv2.hconcat([(result.pred_sem_seg.data.permute(1, 2, 0).cpu().numpy() + 0) * 50., label])

    # Save the combined image
    cv2.imwrite(os.path.join(output_dir, file), combined_img)
    cv2.imwrite(os.path.join(output_dir, "orig_" + file), cv2.imread(image_path))
    # Save the prediction only
    #cv2.imwrite(os.path.join(output_dir, "prediction_" + file), (result.pred_sem_seg.data.permute(1, 2, 0).cpu().numpy() + 0) * 50.)

# %%
import json
import numpy as np
import cv2
import pycocotools
from pycocotools.coco import COCO
from pycocotools import mask as mask_utils
def encode_rle(mask):
    rle = mask_utils.encode(np.asfortranarray(mask))
    return {
        "counts": rle["counts"].decode(),  # Convert the bytes to a string
        "size": list(rle["size"])
    }

def create_coco_dict(file):
    '''
    Creates coco dataset
    '''
    files = {}
    files['info'] = {"year": 2222, "version": "1.0", "description": "Object detection", "date_created": "2222"}
    files['licenses'] = [{'id': 1,
      'name': 'GNU General Public License v3.0',
      'url': 'https://github.com/zhiqwang/yolov5-rt-stack/blob/master/LICENSE'}]
    files["type"] = "instances"
    files['categories'] = []
    files["annotations"] = []
    files['images'] = []
    files['categories'].append({'id': 0, 'name': "0", 'supercategory': "0"})
    all_annos = 0                    
    im = cv2.imread(file, 0)
    empty = np.zeros_like(im)
    files['images'].append({'date_captured': '2021',
                              'file_name': file,
                              'id': 0,
                              'height': im.shape[0],
                              'width': im.shape[1]})
                      
    tmp = im.copy()
    #get contours of image
    contours,hierarchy = cv2.findContours(tmp, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    #black images to draw the contours on
    blank = np.zeros_like(tmp)

    for cnt, cont in enumerate(contours):
        segmentation = []
        xmin, ymin, width, height = cv2.boundingRect(cont) #bounding box
        if width * height < 3:
            continue
        image_height = im.shape[0]
        image_width = im.shape[1]
        
        #draw contour for verification
        rle_mask = encode_rle(tmp.astype(np.uint8))
        files["annotations"].append({
            'segmentation': rle_mask,
            'area': width * height,
            'image_id': 0,
            'iscrowd': 0,
            'bbox': [xmin, ymin, width, height],
            "category_id": 0,
            "id": all_annos
        })
        all_annos += 1
        cv2.drawContours(empty, [cont], 0, 255, -1)  
        cv2.imwrite("drawn_contours.png", empty)
    
    return files
  
filename = "test_image.png" #TODO: insert your filename here!
di = create_coco_dict(filename)
with open("test.json", "w") as handle:
    json.dump(di, handle)

coco_annotation = COCO("test.json")
ann_ids = coco_annotation.getAnnIds(imgIds=[0], iscrowd=None)
anns = coco_annotation.loadAnns(ann_ids)

mask = np.zeros(cv2.imread(filename,0).shape)
for i in range(len(anns)):
    mask += coco_annotation.annToMask(anns[i])
cv2.imwrite("coco_out.png", mask * 255.)

#assert(np.array_equal(cv2.imread("coco_out.png",0),cv2.imread("drawn_contours.png", 0))) #images are not equal even though they should be(?)

# %%
import torch

# %%
x = torch.load(r"C:\HSA\HSA-Data\custom_models\verified_models\Custom - HypermyocardiocyteNet V4\instance_seg\001.pt")

# %%
x["custom_data"]

# %%
y = torch.load(r"C:\HSA\HSA-Data\custom_models\verified_models\Custom - HypermyocardiocyteNet V6\instance_seg\001.pt")

# %%
y["custom_data"]
